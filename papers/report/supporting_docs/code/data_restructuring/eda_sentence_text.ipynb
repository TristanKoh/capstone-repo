# %% [markdown]
# ## EDA on sentence_text

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\Tristan\\Desktop\\Capstone ML and Data privacy\\capstone-repo\\code'

# %%
import pandas as pd
import sklearn
import seaborn as sns

PATH = r"../dataset/concat_sentence_text.csv"

# %%
df = pd.read_csv(PATH)
df.head()
# Out:
#                                        sentence_text  \
# 0               IP ADDRESS, COOKIES, AND WEB BEACONS
# 1               IP ADDRESS, COOKIES, AND WEB BEACONS
# 2  IP addresses will be collected, along with inf...
# 3  The information that our products collect incl...
# 4  The information that our products collect incl...
#
#                                      practice   modality
# 0  Identifier_Cookie_or_similar_Tech_1stParty  PERFORMED
# 1              Identifier_IP_Address_1stParty  PERFORMED
# 2              Identifier_IP_Address_1stParty  PERFORMED
# 3  Identifier_Cookie_or_similar_Tech_1stParty  PERFORMED
# 4              Identifier_IP_Address_1stParty  PERFORMED

# %%
# Number of records
print(len(df))
# Out:
# 18829

# %% [markdown]
# ### Counts per each practice
# Taking into account that one sentence can have multiple labels

# %%
# Counts of each practice
df_by_practice = df["practice"].value_counts(sort = True).rename_axis('practice').reset_index(name = "counts")
df_by_practice
# Out:
#                                       practice  counts
# 0   Identifier_Cookie_or_similar_Tech_1stParty    2107
# 1              Contact_E_Mail_Address_1stParty    2106
# 2                            Location_1stParty    1514
# 3   Identifier_Cookie_or_similar_Tech_3rdParty    1250
# 4               Identifier_IP_Address_1stParty    1005
# 5                Contact_Phone_Number_1stParty     970
# 6                Identifier_Device_ID_1stParty     697
# 7              Contact_Postal_Address_1stParty     597
# 8                                          SSO     504
# 9                     Demographic_Age_1stParty     428
# 10               Contact_Address_Book_1stParty     404
# 11              Identifier_IP_Address_3rdParty     403
# 12                   Contact_Password_1stParty     399
# 13                            Contact_1stParty     391
# 14                       Location_GPS_1stParty     384
# 15                           Location_3rdParty     374
# 16                                Facebook_SSO     372
# 17                 Demographic_Gender_1stParty     341
# 18               Identifier_Device_ID_3rdParty     293
# 19                      Location_WiFi_1stParty     292
# 20                        Demographic_1stParty     264
# 21                   Identifier_Ad_ID_1stParty     252
# 22             Contact_E_Mail_Address_3rdParty     247
# 23                Location_IP_Address_1stParty     240
# 24                 Location_Bluetooth_1stParty     214
# 25                Location_Cell_Tower_1stParty     208
# 26                   Identifier_Ad_ID_3rdParty     193
# 27                     Identifier_MAC_1stParty     185
# 28                        Contact_ZIP_1stParty     179
# 29                         Identifier_1stParty     178
# 30          Identifier_Mobile_Carrier_1stParty     155
# 31                        Demographic_3rdParty     142
# 32                       Contact_City_1stParty     128
# 33             Contact_Postal_Address_3rdParty     122
# 34               Contact_Phone_Number_3rdParty     105
# 35                Location_IP_Address_3rdParty     104
# 36                       Location_GPS_3rdParty      99
# 37                    Identifier_IMEI_1stParty      98
# 38                      Location_WiFi_3rdParty      88
# 39                    Demographic_Age_3rdParty      86
# 40                     Identifier_MAC_3rdParty      84
# 41                Location_Cell_Tower_3rdParty      82
# 42                         Identifier_3rdParty      72
# 43                 Demographic_Gender_3rdParty      68
# 44                 Location_Bluetooth_3rdParty      66
# 45                            Contact_3rdParty      54
# 46                    Identifier_IMEI_3rdParty      44
# 47              Identifier_SIM_Serial_1stParty      41
# 48          Identifier_Mobile_Carrier_3rdParty      35
# 49                        Contact_ZIP_3rdParty      34
# 50              Identifier_SSID_BSSID_1stParty      33
# 51                   Contact_Password_3rdParty      33
# 52                       Contact_City_3rdParty      24
# 53               Contact_Address_Book_3rdParty      17
# 54                    Identifier_IMSI_1stParty      13
# 55              Identifier_SIM_Serial_3rdParty       5
# 56                    Identifier_IMSI_3rdParty       4
# 57              Identifier_SSID_BSSID_3rdParty       2

# %%
sns.set(rc = {'figure.figsize':(30,15)})
ax = sns.barplot(x = "practice", y = "counts", data = df_by_practice[:10])

# %%
sns.barplot(x = "practice", y = "counts", data = df_by_practice[:])

# %% [markdown]
# ### Sentence length statistics: by word, correlations between length and practice?

# %%
# Duplicate df
df_sentence_statistics = df

import re

# %%
df_sentence_statistics["sentence_length"] = df_sentence_statistics["sentence_text"].apply(lambda sen: len(re.findall(r'\w+', sen)))

# %%
df_sentence_statistics["sentence_length"].describe()
# Out:
# count    18829.000000
# mean        29.779170
# std         22.885182
# min          1.000000
# 25%         16.000000
# 50%         25.000000
# 75%         37.000000
# max        496.000000
# Name: sentence_length, dtype: float64

# %%
# Histogram of sentence length
sns.set(rc = {'figure.figsize':(20,8)})
ax = sns.histplot(x = "sentence_length",  data = df_sentence_statistics)

# %%
## Average Sentence length by type of practice
df_sentence_statistics.groupby(["practice"]).mean().sort_values(by = "sentence_length", ascending=False).head()
# Out:
#                                     sentence_length
# practice
# Identifier_SSID_BSSID_3rdParty            65.500000
# Identifier_IMSI_3rdParty                  54.250000
# Identifier_IMSI_1stParty                  48.153846
# Identifier_Mobile_Carrier_3rdParty        47.057143
# Identifier_SIM_Serial_3rdParty            41.200000

# %%
# Median sentence length by practice
df_sentence_statistics.groupby(["practice"]).median().sort_values(by = "sentence_length", ascending=False).head()
# Out:
#                                 sentence_length
# practice
# Identifier_SSID_BSSID_3rdParty             65.5
# Identifier_SIM_Serial_3rdParty             54.0
# Identifier_IMSI_3rdParty                   47.5
# Identifier_IMSI_1stParty                   44.0
# Contact_ZIP_3rdParty                       41.0

# %%
# Concat to df_by_practice
df_by_practice = pd.merge(left = df_by_practice, right = df_sentence_statistics.groupby(["practice"]).mean(), how = "outer", left_on = "practice", right_on = "practice", suffixes = (None, "_mean"))

# %%
df_by_practice = pd.merge(left = df_by_practice, right = df_sentence_statistics.groupby(["practice"]).median(), how = "outer", left_on = "practice", right_on = "practice", suffixes = (None, "_median"))

# %%
# Sanity check
df_by_practice.head()
# Out:
#                                      practice  counts  sentence_length  \
# 0  Identifier_Cookie_or_similar_Tech_1stParty    2107        25.389654
# 1             Contact_E_Mail_Address_1stParty    2106        28.651472
# 2                           Location_1stParty    1514        29.159181
# 3  Identifier_Cookie_or_similar_Tech_3rdParty    1250        27.318400
# 4              Identifier_IP_Address_1stParty    1005        30.913433
#
#    sentence_length_median
# 0                    22.0
# 1                    25.0
# 2                    24.0
# 3                    24.0
# 4                    27.0

# %%
df_by_practice.rename(columns = {"sentence_length":"sentence_length_mean"}, inplace=True)
df_by_practice.head()
# Out:
#                                      practice  counts  sentence_length_mean  \
# 0  Identifier_Cookie_or_similar_Tech_1stParty    2107             25.389654
# 1             Contact_E_Mail_Address_1stParty    2106             28.651472
# 2                           Location_1stParty    1514             29.159181
# 3  Identifier_Cookie_or_similar_Tech_3rdParty    1250             27.318400
# 4              Identifier_IP_Address_1stParty    1005             30.913433
#
#    sentence_length_median
# 0                    22.0
# 1                    25.0
# 2                    24.0
# 3                    24.0
# 4                    27.0

# %%
# Plotting top 10 sentence statisitcs
sns.set(rc = {'figure.figsize':(30,8)})
ax = sns.barplot(x = "practice", y = "sentence_length_mean",  data = df_by_practice[:10])

# %%
df_by_practice["sentence_length_mean"][:10].describe()
# Out:
# count    10.000000
# mean     29.747511
# std       2.468191
# min      25.389654
# 25%      28.715572
# 50%      29.138353
# 75%      32.011357
# max      33.074766
# Name: sentence_length_mean, dtype: float64

# %% [markdown]
# Not much variation in sentence length for the top 10 frequently recurring practices.

# %%
## Looking at propotion of counts per practice 
df_by_practice["counts_proportion"] = df_by_practice["counts"].apply(lambda count: count / df_by_practice["counts"].sum())

df_by_practice.head(10)
# Out:
#                                      practice  counts  sentence_length_mean  \
# 0  Identifier_Cookie_or_similar_Tech_1stParty    2107             25.389654
# 1             Contact_E_Mail_Address_1stParty    2106             28.651472
# 2                           Location_1stParty    1514             29.159181
# 3  Identifier_Cookie_or_similar_Tech_3rdParty    1250             27.318400
# 4              Identifier_IP_Address_1stParty    1005             30.913433
# 5               Contact_Phone_Number_1stParty     970             29.117526
# 6               Identifier_Device_ID_1stParty     697             32.377331
# 7             Contact_Postal_Address_1stParty     597             28.907873
# 8                                         SSO     504             32.565476
# 9                    Demographic_Age_1stParty     428             33.074766
#
#    sentence_length_median  counts_proportion
# 0                    22.0           0.111902
# 1                    25.0           0.111849
# 2                    24.0           0.080408
# 3                    24.0           0.066387
# 4                    27.0           0.053375
# 5                    25.0           0.051516
# 6                    28.0           0.037017
# 7                    26.0           0.031706
# 8                    28.0           0.026767
# 9                    26.0           0.022731

# %%
# with open(r"../tex_files/my_table.tex", "w") as tf:
#     tf.write(df_by_practice.head(10).to_latex(index = False))

# %%
# Summary statistics of top 10 by mean and median
df_top_10_summary = pd.concat([df_by_practice.head(10)["sentence_length_mean"].describe(), df_by_practice.head(10)["sentence_length_median"].describe()], axis = 1)

df_top_10_summary.head()
# Out:
#        sentence_length_mean  sentence_length_median
# count             10.000000               10.000000
# mean              29.747511               25.500000
# std                2.468191                1.900292
# min               25.389654               22.000000
# 25%               28.715572               24.250000

# %%
with open(r"../tex_files/my_table.tex", "w") as tf:
    tf.write(df_top_10_summary.to_latex(index = True))

# %%
df_by_practice["counts_proportion"][:10].sum()
# Out:
# 0.5936587179351003

# %% [markdown]
# Top 10 frequently recurring practices compose of 60% of all practices in the dataset.

# %% [markdown]
# ### Looking at the practices with the fewest counts

# %%
df_by_practice.tail(10)
# Out:
#                               practice  counts  sentence_length_mean  \
# 48  Identifier_Mobile_Carrier_3rdParty      35             47.057143
# 49                Contact_ZIP_3rdParty      34             40.176471
# 50      Identifier_SSID_BSSID_1stParty      33             28.060606
# 51           Contact_Password_3rdParty      33             24.181818
# 52               Contact_City_3rdParty      24             18.000000
# 53       Contact_Address_Book_3rdParty      17             39.647059
# 54            Identifier_IMSI_1stParty      13             48.153846
# 55      Identifier_SIM_Serial_3rdParty       5             41.200000
# 56            Identifier_IMSI_3rdParty       4             54.250000
# 57      Identifier_SSID_BSSID_3rdParty       2             65.500000
#
#     sentence_length_median  counts_proportion
# 48                    30.0           0.001859
# 49                    41.0           0.001806
# 50                    24.0           0.001753
# 51                    20.0           0.001753
# 52                    14.0           0.001275
# 53                    34.0           0.000903
# 54                    44.0           0.000690
# 55                    54.0           0.000266
# 56                    47.5           0.000212
# 57                    65.5           0.000106

# %%
df_by_practice.tail(10)["counts_proportion"].sum()
# Out:
# 0.010621913006532478

# %%
# with open(r"../tex_files/my_table.tex", "w") as tf:
#     tf.write(df_by_practice.tail(10).to_latex(index = False))

# %%
df_by_practice.tail(10).describe()
# Out:
#           counts  sentence_length_mean  sentence_length_median  \
# count  10.000000             10.000000               10.000000
# mean   20.000000             40.622694               37.400000
# std    13.490738             14.314263               16.055113
# min     2.000000             18.000000               14.000000
# 25%     7.000000             30.957219               25.500000
# 50%    20.500000             40.688235               37.500000
# 75%    33.000000             47.879670               46.625000
# max    35.000000             65.500000               65.500000
#
#        counts_proportion
# count          10.000000
# mean            0.001062
# std             0.000716
# min             0.000106
# 25%             0.000372
# 50%             0.001089
# 75%             0.001753
# max             0.001859

# %% [markdown]
# Much more variation with higher std: around 38 words vs 2.4 for the top 10 most frequently recurring.
# But then could be because of low frequency. So might not be statisitcally significant.
