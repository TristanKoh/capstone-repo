# %%
import pandas as pd
import numpy as np

from sklearn.pipeline import make_pipeline
from sklearn.feature_extraction import text
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import classification_report

from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV

from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import SGDClassifier

PATH_SENTENCE_TEXT = r"../dataset/concat_sentence_text.csv"
PATH_SEGMENT_TEXT = r"../dataset/concat_segment_text.csv"

# %%
# Data restructuring
df = pd.read_csv(PATH_SEGMENT_TEXT)
df_value_counts = df["practice"].value_counts().rename_axis("practice").reset_index(name = "counts")
df = df.fillna("None")

top_5_cats = list(df_value_counts["practice"][:5])
df = df[df["practice"].isin(top_5_cats)]

df.head()
# Out:
#                                          segment_text  \
# 2   2. THE INFORMATION WE COLLECT The information ...
# 3   2. THE INFORMATION WE COLLECT The information ...
# 4   2.2 In addition, we store certain information ...
# 12  2.6 Most browsers are initially set to accept ...
# 13  B) PERSONAL DATA, INCLUDING YOUR E-MAIL ADDRES...
#
#                                       practice   modality
# 2   Identifier_Cookie_or_similar_Tech_1stParty  PERFORMED
# 3               Identifier_IP_Address_1stParty  PERFORMED
# 4   Identifier_Cookie_or_similar_Tech_1stParty  PERFORMED
# 12  Identifier_Cookie_or_similar_Tech_1stParty  PERFORMED
# 13             Contact_E_Mail_Address_1stParty  PERFORMED

# %% [markdown]
# ### Tuning logistic with tfidf

# %%
vectorizer = TfidfVectorizer(stop_words={'english'}, strip_accents='ascii', ngram_range = (1, 4))
logistic = LogisticRegression(random_state = 1, max_iter = 500, n_jobs = -1, multi_class = "ovr")

# %%
x_tf = vectorizer.fit_transform(df["segment_text"])
x_train, x_test, y_train, y_test = train_test_split(x_tf, df["practice"], test_size=0.2, random_state=0)

# %%
param_grid = {
    "solver" : ["liblinear", "lbfgs", "sag"],
    "penalty" : ["l1", "l2", "elasticnet"],
    "C" : [0.001, 0.01, 0.1, 1]
}

# %%
grid_search = GridSearchCV(logistic, param_grid, scoring = "roc_auc", cv = 3, verbose = 1, n_jobs=-1)

# %%
grid_search.fit(x_train, y_train)
# Out:
# Fitting 3 folds for each of 36 candidates, totalling 108 fits
# c:\Users\Tristan\Desktop\Capstone ML and Data privacy\capstone-repo\capstone\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 60 fits failed out of a total of 108.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 12 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Tristan\Desktop\Capstone ML and Data privacy\capstone-repo\capstone\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Tristan\Desktop\Capstone ML and Data privacy\capstone-repo\capstone\lib\site-packages\sklearn\linear_model\_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "c:\Users\Tristan\Desktop\Capstone ML and Data privacy\capstone-repo\capstone\lib\site-packages\sklearn\linear_model\_logistic.py", line 449, in _check_solver
#     % (solver, penalty)
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 12 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Tristan\Desktop\Capstone ML and Data privacy\capstone-repo\capstone\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Tristan\Desktop\Capstone ML and Data privacy\capstone-repo\capstone\lib\site-packages\sklearn\linear_model\_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "c:\Users\Tristan\Desktop\Capstone ML and Data privacy\capstone-repo\capstone\lib\site-packages\sklearn\linear_model\_logistic.py", line 449, in _check_solver
#     % (solver, penalty)
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 12 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Tristan\Desktop\Capstone ML and Data privacy\capstone-repo\capstone\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Tristan\Desktop\Capstone ML and Data privacy\capstone-repo\capstone\lib\site-packages\sklearn\linear_model\_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "c:\Users\Tristan\Desktop\Capstone ML and Data privacy\capstone-repo\capstone\lib\site-packages\sklearn\linear_model\_logistic.py", line 459, in _check_solver
#     solver
# ValueError: Only 'saga' solver supports elasticnet penalty, got solver=liblinear.
#
# --------------------------------------------------------------------------------
# 12 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Tristan\Desktop\Capstone ML and Data privacy\capstone-repo\capstone\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Tristan\Desktop\Capstone ML and Data privacy\capstone-repo\capstone\lib\site-packages\sklearn\linear_model\_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "c:\Users\Tristan\Desktop\Capstone ML and Data privacy\capstone-repo\capstone\lib\site-packages\sklearn\linear_model\_logistic.py", line 449, in _check_solver
#     % (solver, penalty)
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
# --------------------------------------------------------------------------------
# 12 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Tristan\Desktop\Capstone ML and Data privacy\capstone-repo\capstone\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Tristan\Desktop\Capstone ML and Data privacy\capstone-repo\capstone\lib\site-packages\sklearn\linear_model\_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "c:\Users\Tristan\Desktop\Capstone ML and Data privacy\capstone-repo\capstone\lib\site-packages\sklearn\linear_model\_logistic.py", line 449, in _check_solver
#     % (solver, penalty)
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\Tristan\Desktop\Capstone ML and Data privacy\capstone-repo\capstone\lib\site-packages\sklearn\model_selection\_search.py:972: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#   category=UserWarning,
# c:\Users\Tristan\Desktop\Capstone ML and Data privacy\capstone-repo\capstone\lib\site-packages\sklearn\linear_model\_logistic.py:1526: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 12.
#   " = {}.".format(effective_n_jobs(self.n_jobs))
# GridSearchCV(cv=3,
#              estimator=LogisticRegression(max_iter=500, multi_class='ovr',
#                                           n_jobs=-1, random_state=1),
#              n_jobs=-1,
#              param_grid={'C': [0.001, 0.01, 0.1, 1],
#                          'penalty': ['l1', 'l2', 'elasticnet'],
#                          'solver': ['liblinear', 'lbfgs', 'sag']},
#              scoring='roc_auc', verbose=1)

# %%
grid_search.best_estimator_
# Out:
# LogisticRegression(C=0.001, max_iter=500, multi_class='ovr', n_jobs=-1,
#                    penalty='l1', random_state=1, solver='liblinear')

# %%
pd.DataFrame(grid_search.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        1.104596      0.078076         0.006999        0.000817   0.001
# 1        0.030547      0.002316         0.000000        0.000000   0.001
# 2        0.037703      0.008991         0.000000        0.000000   0.001
# 3        7.937775      3.788354         0.019649        0.018618   0.001
# 4       42.653777      0.700033         0.007001        0.001641   0.001
# 5       33.284264      1.089195         0.034998        0.038263   0.001
# 6        0.058994      0.031495         0.000000        0.000000   0.001
# 7        0.027327      0.008265         0.000000        0.000000   0.001
# 8        0.033663      0.018659         0.000000        0.000000   0.001
# 9       14.144637      4.206433         0.051004        0.063644    0.01
# 10       0.072674      0.005908         0.000000        0.000000    0.01
# 11       0.067016      0.005915         0.000000        0.000000    0.01
# 12       5.204924      2.486510         0.006667        0.006600    0.01
# 13      39.281597      0.569772         0.002663        0.000468    0.01
# 14      13.416750      1.209057         0.011673        0.010857    0.01
# 15       0.179333      0.113677         0.000000        0.000000    0.01
# 16       0.202341      0.036020         0.000000        0.000000    0.01
# 17       0.181332      0.035370         0.000000        0.000000    0.01
# 18      10.142553      2.683558         0.003340        0.000950     0.1
# 19       0.170663      0.049995         0.000000        0.000000     0.1
# 20       0.081652      0.009106         0.000000        0.000000     0.1
# 21       8.639523      0.264463         0.004647        0.000936     0.1
# 22      27.321864      1.585520         0.001331        0.000473     0.1
# 23       5.904939      0.674710         0.007006        0.002161     0.1
# 24       0.083008      0.011303         0.000000        0.000000     0.1
# 25       0.044332      0.004192         0.000000        0.000000     0.1
# 26       0.044665      0.003301         0.000000        0.000000     0.1
# 27      16.533353      1.390127         0.002337        0.000472       1
# 28       0.099667      0.056687         0.000000        0.000000       1
# 29       0.084011      0.006979         0.000000        0.000000       1
# 30       7.750421      0.380812         0.013671        0.015087       1
# 31      25.033515      0.434357         0.001334        0.000452       1
# 32       3.483205      0.435166         0.002332        0.000472       1
# 33       0.069665      0.022303         0.000000        0.000000       1
# 34       0.073000      0.015299         0.000000        0.000000       1
# 35       0.048664      0.014972         0.000000        0.000000       1
#
#    param_penalty param_solver  \
# 0             l1    liblinear
# 1             l1        lbfgs
# 2             l1          sag
# 3             l2    liblinear
# 4             l2        lbfgs
# 5             l2          sag
# 6     elasticnet    liblinear
# 7     elasticnet        lbfgs
# 8     elasticnet          sag
# 9             l1    liblinear
# 10            l1        lbfgs
# 11            l1          sag
# 12            l2    liblinear
# 13            l2        lbfgs
# 14            l2          sag
# 15    elasticnet    liblinear
# 16    elasticnet        lbfgs
# 17    elasticnet          sag
# 18            l1    liblinear
# 19            l1        lbfgs
# 20            l1          sag
# 21            l2    liblinear
# 22            l2        lbfgs
# 23            l2          sag
# 24    elasticnet    liblinear
# 25    elasticnet        lbfgs
# 26    elasticnet          sag
# 27            l1    liblinear
# 28            l1        lbfgs
# 29            l1          sag
# 30            l2    liblinear
# 31            l2        lbfgs
# 32            l2          sag
# 33    elasticnet    liblinear
# 34    elasticnet        lbfgs
# 35    elasticnet          sag
#
#                                                params  split0_test_score  \
# 0   {'C': 0.001, 'penalty': 'l1', 'solver': 'libli...                NaN
# 1    {'C': 0.001, 'penalty': 'l1', 'solver': 'lbfgs'}                NaN
# 2      {'C': 0.001, 'penalty': 'l1', 'solver': 'sag'}                NaN
# 3   {'C': 0.001, 'penalty': 'l2', 'solver': 'libli...                NaN
# 4    {'C': 0.001, 'penalty': 'l2', 'solver': 'lbfgs'}                NaN
# 5      {'C': 0.001, 'penalty': 'l2', 'solver': 'sag'}                NaN
# 6   {'C': 0.001, 'penalty': 'elasticnet', 'solver'...                NaN
# 7   {'C': 0.001, 'penalty': 'elasticnet', 'solver'...                NaN
# 8   {'C': 0.001, 'penalty': 'elasticnet', 'solver'...                NaN
# 9   {'C': 0.01, 'penalty': 'l1', 'solver': 'liblin...                NaN
# 10    {'C': 0.01, 'penalty': 'l1', 'solver': 'lbfgs'}                NaN
# 11      {'C': 0.01, 'penalty': 'l1', 'solver': 'sag'}                NaN
# 12  {'C': 0.01, 'penalty': 'l2', 'solver': 'liblin...                NaN
# 13    {'C': 0.01, 'penalty': 'l2', 'solver': 'lbfgs'}                NaN
# 14      {'C': 0.01, 'penalty': 'l2', 'solver': 'sag'}                NaN
# 15  {'C': 0.01, 'penalty': 'elasticnet', 'solver':...                NaN
# 16  {'C': 0.01, 'penalty': 'elasticnet', 'solver':...                NaN
# 17  {'C': 0.01, 'penalty': 'elasticnet', 'solver':...                NaN
# 18  {'C': 0.1, 'penalty': 'l1', 'solver': 'libline...                NaN
# 19     {'C': 0.1, 'penalty': 'l1', 'solver': 'lbfgs'}                NaN
# 20       {'C': 0.1, 'penalty': 'l1', 'solver': 'sag'}                NaN
# 21  {'C': 0.1, 'penalty': 'l2', 'solver': 'libline...                NaN
# 22     {'C': 0.1, 'penalty': 'l2', 'solver': 'lbfgs'}                NaN
# 23       {'C': 0.1, 'penalty': 'l2', 'solver': 'sag'}                NaN
# 24  {'C': 0.1, 'penalty': 'elasticnet', 'solver': ...                NaN
# 25  {'C': 0.1, 'penalty': 'elasticnet', 'solver': ...                NaN
# 26  {'C': 0.1, 'penalty': 'elasticnet', 'solver': ...                NaN
# 27   {'C': 1, 'penalty': 'l1', 'solver': 'liblinear'}                NaN
# 28       {'C': 1, 'penalty': 'l1', 'solver': 'lbfgs'}                NaN
# 29         {'C': 1, 'penalty': 'l1', 'solver': 'sag'}                NaN
# 30   {'C': 1, 'penalty': 'l2', 'solver': 'liblinear'}                NaN
# 31       {'C': 1, 'penalty': 'l2', 'solver': 'lbfgs'}                NaN
# 32         {'C': 1, 'penalty': 'l2', 'solver': 'sag'}                NaN
# 33  {'C': 1, 'penalty': 'elasticnet', 'solver': 'l...                NaN
# 34  {'C': 1, 'penalty': 'elasticnet', 'solver': 'l...                NaN
# 35  {'C': 1, 'penalty': 'elasticnet', 'solver': 's...                NaN
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0                 NaN                NaN              NaN             NaN
# 1                 NaN                NaN              NaN             NaN
# 2                 NaN                NaN              NaN             NaN
# 3                 NaN                NaN              NaN             NaN
# 4                 NaN                NaN              NaN             NaN
# 5                 NaN                NaN              NaN             NaN
# 6                 NaN                NaN              NaN             NaN
# 7                 NaN                NaN              NaN             NaN
# 8                 NaN                NaN              NaN             NaN
# 9                 NaN                NaN              NaN             NaN
# 10                NaN                NaN              NaN             NaN
# 11                NaN                NaN              NaN             NaN
# 12                NaN                NaN              NaN             NaN
# 13                NaN                NaN              NaN             NaN
# 14                NaN                NaN              NaN             NaN
# 15                NaN                NaN              NaN             NaN
# 16                NaN                NaN              NaN             NaN
# 17                NaN                NaN              NaN             NaN
# 18                NaN                NaN              NaN             NaN
# 19                NaN                NaN              NaN             NaN
# 20                NaN                NaN              NaN             NaN
# 21                NaN                NaN              NaN             NaN
# 22                NaN                NaN              NaN             NaN
# 23                NaN                NaN              NaN             NaN
# 24                NaN                NaN              NaN             NaN
# 25                NaN                NaN              NaN             NaN
# 26                NaN                NaN              NaN             NaN
# 27                NaN                NaN              NaN             NaN
# 28                NaN                NaN              NaN             NaN
# 29                NaN                NaN              NaN             NaN
# 30                NaN                NaN              NaN             NaN
# 31                NaN                NaN              NaN             NaN
# 32                NaN                NaN              NaN             NaN
# 33                NaN                NaN              NaN             NaN
# 34                NaN                NaN              NaN             NaN
# 35                NaN                NaN              NaN             NaN
#
#     rank_test_score
# 0                 1
# 1                20
# 2                21
# 3                22
# 4                23
# 5                24
# 6                25
# 7                26
# 8                27
# 9                28
# 10               29
# 11               30
# 12               31
# 13               32
# 14               33
# 15               34
# 16               19
# 17               18
# 18               17
# 19                8
# 20                2
# 21                3
# 22                4
# 23                5
# 24                6
# 25                7
# 26                9
# 27               16
# 28               10
# 29               11
# 30               12
# 31               13
# 32               14
# 33               15
# 34               35
# 35               36

# %%
logistic_default = LogisticRegression(random_state = 1, max_iter = 500, n_jobs = -1, multi_class = "ovr")

# %%
logistic_default = logistic_default.fit(x_train, y_train)
y_pred = logistic_default.predict(x_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#                                             precision    recall  f1-score   support
#
#            Contact_E_Mail_Address_1stParty       0.51      0.74      0.60       224
#              Contact_Phone_Number_1stParty       0.24      0.11      0.15       121
# Identifier_Cookie_or_similar_Tech_1stParty       0.78      0.85      0.81       171
#             Identifier_IP_Address_1stParty       0.45      0.36      0.40       108
#                          Location_1stParty       0.63      0.53      0.57       164
#
#                                   accuracy                           0.57       788
#                                  macro avg       0.52      0.52      0.51       788
#                               weighted avg       0.54      0.57      0.55       788

# %% [markdown]
# ### Tuning SVC with Tfidf

# %%
svc = SVC(probability=True)

# %%
param_grid = {
    "kernel" : ["linear", "poly", "rbf", "sigmoid"],
    "gamma" : [0.1, 1, 10, 100],
    "C" : [0.1, 1, 10, 100],
    "degree" : range(4, 50)
}

# %%
grid_search = RandomizedSearchCV(svc, param_grid, scoring = "roc_auc", cv = 3, verbose = 3, random_state=1, n_jobs=-1)

# %%
grid_search.fit(x_train, y_train)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
