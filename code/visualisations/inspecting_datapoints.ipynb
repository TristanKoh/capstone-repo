# %%
import pandas as pd
import random

FILEPATH_1 = r"../../model_performance/individual_classifiers/logistic+glove.csv"
FILEPATH_2 = r"../../model_performance/individual_classifiers/logistic+tfidf.csv"
FILEPATH_3 = r"../../model_performance/individual_classifiers/svc+glove.csv"
FILEPATH_4 = r"../../model_performance/individual_classifiers/svc+tfidf.csv"

# %% [markdown]
# ### Logistic and glove

# %%
df_logistic_glove = pd.read_csv(FILEPATH_1, index_col=0)
df_logistic_glove.head()
# Out:
#                                             segment_text  \
# 6869   Devexpert.NET Mobile Apps Privacy Policy This ...
# 8057   We only collect personal data in order to proc...
# 17290  Use of cookies and other technology to collect...
# 11738  Use of Information We use information to provi...
# 11660  We do not collect information about the locati...
#
#                                          practice  \
# 6869   Identifier_Cookie_or_similar_Tech_1stParty
# 8057              Contact_E_Mail_Address_1stParty
# 17290  Identifier_Cookie_or_similar_Tech_1stParty
# 11738                           Location_1stParty
# 11660                           Location_1stParty
#
#                                         predicted
# 6869   Identifier_Cookie_or_similar_Tech_1stParty
# 8057              Contact_E_Mail_Address_1stParty
# 17290  Identifier_Cookie_or_similar_Tech_1stParty
# 11738                           Location_1stParty
# 11660                           Location_1stParty

# %%
df_logistic_tfidf = pd.read_csv(FILEPATH_2, index_col=0)
df_logistic_tfidf.head()
# Out:
#                                             segment_text  \
# 6869   Devexpert.NET Mobile Apps Privacy Policy This ...
# 8057   We only collect personal data in order to proc...
# 17290  Use of cookies and other technology to collect...
# 11738  Use of Information We use information to provi...
# 11660  We do not collect information about the locati...
#
#                                          practice  \
# 6869   Identifier_Cookie_or_similar_Tech_1stParty
# 8057              Contact_E_Mail_Address_1stParty
# 17290  Identifier_Cookie_or_similar_Tech_1stParty
# 11738                           Location_1stParty
# 11660                           Location_1stParty
#
#                                         predicted
# 6869   Identifier_Cookie_or_similar_Tech_1stParty
# 8057              Contact_E_Mail_Address_1stParty
# 17290  Identifier_Cookie_or_similar_Tech_1stParty
# 11738                           Location_1stParty
# 11660                           Location_1stParty

# %%
df_svc_glove = pd.read_csv(FILEPATH_3, index_col=0)
df_svc_glove.head()
# Out:
#                                             segment_text  \
# 6869   Devexpert.NET Mobile Apps Privacy Policy This ...
# 8057   We only collect personal data in order to proc...
# 17290  Use of cookies and other technology to collect...
# 11738  Use of Information We use information to provi...
# 11660  We do not collect information about the locati...
#
#                                          practice  \
# 6869   Identifier_Cookie_or_similar_Tech_1stParty
# 8057              Contact_E_Mail_Address_1stParty
# 17290  Identifier_Cookie_or_similar_Tech_1stParty
# 11738                           Location_1stParty
# 11660                           Location_1stParty
#
#                                         predicted
# 6869   Identifier_Cookie_or_similar_Tech_1stParty
# 8057              Contact_E_Mail_Address_1stParty
# 17290  Identifier_Cookie_or_similar_Tech_1stParty
# 11738                           Location_1stParty
# 11660                           Location_1stParty

# %%
df_svc_tfidf = pd.read_csv(FILEPATH_4, index_col=0)
df_svc_tfidf.head()
# Out:
#                                             segment_text  \
# 6869   Devexpert.NET Mobile Apps Privacy Policy This ...
# 8057   We only collect personal data in order to proc...
# 17290  Use of cookies and other technology to collect...
# 11738  Use of Information We use information to provi...
# 11660  We do not collect information about the locati...
#
#                                          practice  \
# 6869   Identifier_Cookie_or_similar_Tech_1stParty
# 8057              Contact_E_Mail_Address_1stParty
# 17290  Identifier_Cookie_or_similar_Tech_1stParty
# 11738                           Location_1stParty
# 11660                           Location_1stParty
#
#                                         predicted
# 6869   Identifier_Cookie_or_similar_Tech_1stParty
# 8057              Contact_E_Mail_Address_1stParty
# 17290  Identifier_Cookie_or_similar_Tech_1stParty
# 11738                           Location_1stParty
# 11660                           Location_1stParty

# %%
#
# Out:
#                                             segment_text  \
# 3210   INFORMATION WE COLLECT FROM YOU DIRECTLY We ma...
# 10646  We do not store identification or log data tha...
# 15437  To communicate with you and respond to your em...
# 2594   Back To Top 4. HOW IS MY INFORMATION USED? In ...
# 15163  Location Information. You can prevent us from ...
# 10216  We do not collect Personal Information. "Perso...
# 21170  Using Our Services: We receive information whe...
# 20118  WHAT INFORMATION WE COLLECT AND HOW IT IS COLL...
# 11327  The categories of personal data collected incl...
# 16580  The Services do not collect the phone number o...
# 15392  We do not derive your approximate location fro...
# 13256  We may use your Personal Information for both ...
# 14392  your sharing of your biometric information via...
# 9465   We don't use either your personally identifiab...
# 8599   Do Not Track Disclosures in California: Becaus...
# ...
